# %% [markdown]
# ### Class in object oriented programming

# %%
a = 23
print(type(a))
# Out:
# <class 'int'>

# %%
b = -45
print(type(b))
# Out:
# <class 'int'>

# %%
c = 24.59
print(type(c))
# Out:
# <class 'float'>

# %%
d = [4, 5, 6, 7]
print(type(d))
# Out:
# <class 'list'>

# %% [markdown]
# ### Datefrem attributes and methods

# %%
s = {
    "roll_no" : [103, 104, 105],
    "name" : ["Rahul", "Raman", "Aditi"],
    "marks" : [78.3, 84.5, 88.9],
    "hobbies" : ["Singing", "Acting", "Cricket"]
}
print(type(s))
# Out:
# <class 'dict'>

# %%
import pandas as pd

df = pd.DataFrame(s)

df
# Out:
#    roll_no   name  marks  hobbies
# 0      103  Rahul   78.3  Singing
# 1      104  Raman   84.5   Acting
# 2      105  Aditi   88.9  Cricket

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Dataframe Attributes
# 1. df.columns
# 2. df.index
# 3. df.values
# 4. df.shapes
# 5. df.dtypes
# 6. df.size

# %%
df.columns
# Out:
# Index(['roll_no', 'name', 'marks', 'hobbies'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[103, 'Rahul', 78.3, 'Singing'],
#        [104, 'Raman', 84.5, 'Acting'],
#        [105, 'Aditi', 88.9, 'Cricket']], dtype=object)

# %%
df.shape
# Out:
# (3, 4)

# %%
df.dtypes
# Out:
# roll_no      int64
# name        object
# marks      float64
# hobbies     object
# dtype: object

# %%
df.size
# Out:
# 12

# %% [markdown]
# ### Methods of class dataframe
# 1. df.info()
# 2. df.sort_values()
# 3. df.groupby()
# 4. df.sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll_no  3 non-null      int64
#  1   name     3 non-null      object
#  2   marks    3 non-null      float64
#  3   hobbies  3 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.sort_values(by="marks", ascending=False)
# Out:
#    roll_no   name  marks  hobbies
# 2      105  Aditi   88.9  Cricket
# 1      104  Raman   84.5   Acting
# 0      103  Rahul   78.3  Singing

# %%
df["marks"].sum()
# Out:
# np.float64(251.70000000000002)

# %%
df["marks"].mean()
# Out:
# np.float64(83.9)

# %%
df.describe()
# Out:
#        roll_no      marks
# count      3.0   3.000000
# mean     104.0  83.900000
# std        1.0   5.325411
# min      103.0  78.300000
# 25%      103.5  81.400000
# 50%      104.0  84.500000
# 75%      104.5  86.700000
# max      105.0  88.900000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Create a class Person
#  \_\_init\_\_ is constructor function used to define attribute

# %%
class Person:
     
     def __init__(self, name, age, gender, occupation):
          self.name = name
          self.age = age
          self.gender = gender
          self.occupation = occupation
     
     def talk(self):
          print(f"My name is {self.name}")
          print(f"I am {self.age} years old")
          print(f"I am a {self.gender}")
          print(f"I work as a {self.occupation}")

# %%
p1 = Person(name="Rahul", age=28, gender = "male", occupation="Engineer")

# %%
p1

# %%
type(p1)
# Out:
# __main__.Person

# %% [markdown]
# \_\_init\_\_ reffers to current working file in python

# %%
p1.name
# Out:
# 'Rahul'

# %%
p1.age
# Out:
# 28

# %%
p1.gender
# Out:
# 'male'

# %%
p1.talk()
# Out:
# My name is Rahul
# I am 28 years old
# I am a male
# I work as a Engineer

# %%
p2 = Person(name="Aditi", age =25, gender="Female", occupation="HR")

# %%
p2

# %%
type(p2)
# Out:
# __main__.Person

# %%
p2.name
# Out:
# 'Aditi'

# %%
p2.age
# Out:
# 25

# %%
p2.gender
# Out:
# 'Female'

# %%
p2.occupation
# Out:
# 'HR'

# %%
p2.talk()
# Out:
# My name is Aditi
# I am 25 years old
# I am a Female
# I work as a HR

# %%
p2.age
# Out:
# 25

# %%
p2.age = 26

# %%
p2.occupation = "Data Analyst"

# %%
p2.talk()
# Out:
# My name is Aditi
# I am 26 years old
# I am a Female
# I work as a Data Analyst

# %% [markdown]
# ### Create class using dataclasses

# %%
from dataclasses import dataclass

# %%
from typing import Literal

# %%
@dataclass
class Student:
    roll_no : int
    name : str
    marks : float
    gender : Literal["male", "female"]
    hobbies : list[str]

    def get_info(self):
        print(f"Student Roll number : {self.roll_no}")
        print(f"Name : {self.name}")
        print(f"Marks : {self.marks}")
        print(f"Gender : {self.gender}" )
        print(f"Hobbies : {self.hobbies}")

# %%
s1 = Student(
    roll_no= 101,
    name= "Sarthak",
    marks = 73.5,
    gender = "male",
    hobbies = ["Singing", "Cricket"]
)

# %%
s1
# Out:
# Student(roll_no=101, name='Sarthak', marks=73.5, gender='male', hobbies=['Singing', 'Cricket'])

# %%
s1.roll_no
# Out:
# 101

# %%
s1.name
# Out:
# 'Sarthak'

# %%
s1.marks
# Out:
# 73.5

# %%
s1.gender
# Out:
# 'male'

# %%
s1.hobbies
# Out:
# ['Singing', 'Cricket']

# %%
s1.marks = 87.22

# %%
s1.get_info()
# Out:
# Student Roll number : 101
# Name : Sarthak
# Marks : 87.22
# Gender : male
# Hobbies : ['Singing', 'Cricket']

# %%
s2 = Student(
    roll_no = 102,
    name = "Aditi",
    marks = 95.4,
    gender = "female",
    hobbies = ["Cycling", "Swimming"]
)

# %%
s2
# Out:
# Student(roll_no=102, name='Aditi', marks=95.4, gender='female', hobbies=['Cycling', 'Swimming'])

# %%
s2.name
# Out:
# 'Aditi'

# %%
s2.hobbies
# Out:
# ['Cycling', 'Swimming']

# %%
s2.gender
# Out:
# 'female'

# %%
s2.gender
# Out:
# 'female'

# %%
s2.get_info()
# Out:
# Student Roll number : 102
# Name : Aditi
# Marks : 95.4
# Gender : female
# Hobbies : ['Cycling', 'Swimming']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
@dataclass
class Account:
    ac_no:int
    name : str
    bal : int|float

    def check_balance(self):
        print(f"Current balance in account {self.ac_no} is {self.bal:.2f} INR")

    def deposit(self, amt: int|float):
        self.bal = self.bal + amt
        print(f"Amount of {amt} INR Deposit in {self.ac_no}")

    def withdraw(self, amt: int|float):
        if self.bal < amt:
            raise ValueError("Insufficient Balance")
        else:
            self.bal = self.bal - amt
            print(f"Amount of {amt} INR withdrawn from {self.ac_no}")

    def transfer(self, amt: int|float, ac: 'Account'):
        self.withdraw(amt)
        ac.deposit(amt)

# %%
a1 = Account(ac_no=1234, name="Suresh", bal = 2000)
a1
# Out:
# Account(ac_no=1234, name='Suresh', bal=2000)

# %%
a1.ac_no
# Out:
# 1234

# %%
a1.name
# Out:
# 'Suresh'

# %%
a1.bal
# Out:
# 2000

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 2000.00 INR

# %% [markdown]
# ### Deposit

# %%
a1.deposit(800)
# Out:
# Amount of 800 INR Deposit in 1234

# %%
a1.bal
# Out:
# 2800

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 2800.00 INR

# %% [markdown]
# ### Withdraw

# %%
a1.withdraw(5000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 a1.withdraw(5000)
#
# Cell In[68], line 16, in Account.withdraw(self, amt)
#      14 def withdraw(self, amt: int|float):
#      15     if self.bal < amt:
# ---> 16         raise ValueError("Insufficient Balance")
#      17     else:
#      18         self.bal = self.bal - amt
#
# ValueError: Insufficient Balance

# %%
a1.withdraw(650)
# Out:
# Amount of 650 INR withdrawn from 1234

# %% [markdown]
# ### Transfer

# %%
a2 = Account(ac_no=6789, name = "Priya", bal=1200)
a2
# Out:
# Account(ac_no=6789, name='Priya', bal=1200)

# %%
type(a2)
# Out:
# __main__.Account

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 2150.00 INR

# %%
a2.check_balance()
# Out:
# Current balance in account 6789 is 1200.00 INR

# %%
# a1 wants to transfer to a2
a1.transfer(3000, a2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 2
#       1 # a1 wants to transfer to a2
# ----> 2 a1.transfer(3000, a2)
#
# Cell In[68], line 22, in Account.transfer(self, amt, ac)
#      21 def transfer(self, amt: int|float, ac: 'Account'):
# ---> 22     self.withdraw(amt)
#      23     ac.deposit(amt)
#
# Cell In[68], line 16, in Account.withdraw(self, amt)
#      14 def withdraw(self, amt: int|float):
#      15     if self.bal < amt:
# ---> 16         raise ValueError("Insufficient Balance")
#      17     else:
#      18         self.bal = self.bal - amt
#
# ValueError: Insufficient Balance

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 2150.00 INR

# %%
a2.check_balance()
# Out:
# Current balance in account 6789 is 1200.00 INR

# %%
a1.transfer(380, a2)
# Out:
# Amount of 380 INR withdrawn from 1234
# Amount of 380 INR Deposit in 6789

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 1770.00 INR

# %%
a2.check_balance()
# Out:
# Current balance in account 6789 is 1580.00 INR

# %%
# a2 wants to transfer to a1
a2.transfer(800, a1)
# Out:
# Amount of 800 INR withdrawn from 6789
# Amount of 800 INR Deposit in 1234

# %%
a2.check_balance()
# Out:
# Current balance in account 6789 is 780.00 INR

# %%
a1.check_balance()
# Out:
# Current balance in account 1234 is 2570.00 INR
