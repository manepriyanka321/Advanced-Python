# %% [markdown]
# ### Stock Market API Project

# %% [markdown]
# Collect stock data for any given company using RapidAPI

# %% [markdown]
# 1. Create an account on RapidAPI - https://rapidapi.com/auth/sign-up
# 2. Alpha vantage API - https://rapidapi.com/alphavantage/api/alpha-vantage

# %% [markdown]
# ### INSTALL REQUIRED PACKAGES

# %%
# %pip install python-dotenv requests
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from requests) (2025.1.31)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Loading API key from .env file

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("API_KEY")

# %% [markdown]
# ### Symbol Search Fnnctionality
#
# ![image.png](attachment:image.png)

# %%
import requests

import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":"State Bank Of India","function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()

data
# Out:
# {'bestMatches': [{'1. symbol': 'SBIN.BSE',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'India/Bombay',
#    '5. marketOpen': '09:15',
#    '6. marketClose': '15:30',
#    '7. timezone': 'UTC+5.5',
#    '8. currency': 'INR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBKFF',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SID.FRK',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBID.LON',
#    '2. name': 'State Bank of India GDR',
#    '3. type': 'Equity',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'USD',
#    '9. matchScore': '0.9048'}]}

# %%
type(data)
# Out:
# dict

# %%
symbols = data["bestMatches"]
symbols
# Out:
# [{'1. symbol': 'SBIN.BSE',
#   '2. name': 'State Bank of India',
#   '3. type': 'Equity',
#   '4. region': 'India/Bombay',
#   '5. marketOpen': '09:15',
#   '6. marketClose': '15:30',
#   '7. timezone': 'UTC+5.5',
#   '8. currency': 'INR',
#   '9. matchScore': '1.0000'},
#  {'1. symbol': 'SBKFF',
#   '2. name': 'State Bank of India',
#   '3. type': 'Equity',
#   '4. region': 'United States',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-04',
#   '8. currency': 'USD',
#   '9. matchScore': '1.0000'},
#  {'1. symbol': 'SID.FRK',
#   '2. name': 'State Bank of India',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '1.0000'},
#  {'1. symbol': 'SBID.LON',
#   '2. name': 'State Bank of India GDR',
#   '3. type': 'Equity',
#   '4. region': 'United Kingdom',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '16:30',
#   '7. timezone': 'UTC+01',
#   '8. currency': 'USD',
#   '9. matchScore': '0.9048'}]

# %%
symbol_new = {}
for i in symbols:
    s = i["1. symbol"]
    symbol_new[s] = [i['2. name'], i['4. region'], i['8. currency']]

# %%
symbol_new
# Out:
# {'SBIN.BSE': ['State Bank of India', 'India/Bombay', 'INR'],
#  'SBKFF': ['State Bank of India', 'United States', 'USD'],
#  'SID.FRK': ['State Bank of India', 'Frankfurt', 'EUR'],
#  'SBID.LON': ['State Bank of India GDR', 'United Kingdom', 'USD']}

# %% [markdown]
# ### From above symbols I want to get details for "SBIN.BSE
#
# ![image.png](attachment:image.png)

# %%
import requests

import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"SBIN.BSE","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data2 = response.json()

data2
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SBIN.BSE',
#   '3. Last Refreshed': '2025-03-12',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-03-12': {'1. open': '729.9500',
#    '2. high': '736.5000',
#    '3. low': '719.2000',
#    '4. close': '722.9000',
#    '5. volume': '198814'},
#   '2025-03-11': {'1. open': '724.9000',
#    '2. high': '733.9000',
#    '3. low': '722.5000',
#    '4. close': '729.9500',
#    '5. volume': '285624'},
#   '2025-03-10': {'1. open': '732.9500',
#    '2. high': '738.4500',
#    '3. low': '727.0500',
#    '4. close': '728.3500',
#    '5. volume': '339175'},
#   '2025-03-07': {'1. open': '732.9500',
#    '2. high': '734.9000',
#    '3. low': '727.9500',
#    '4. close': '732.7500',
#    '5. volume': '288192'},
#   '2025-03-06': {'1. open': '737.9500',
#    '2. high': '737.9500',
#    '3. low': '727.1000',
#    '4. close': '731.9500',
#    '5. volume': '321519'},
#   '2025-03-05': {'1. open': '718.8500',
#    '2. high': '731.0000',
#    '3. low': '717.8000',
#    '4. close': '730.2500',
#    '5. volume': '628448'},
#   '2025-03-04': {'1. open': '693.4000',
#    '2. high': '718.1500',
#    '3. low': '692.1500',
#    '4. close': '716.1500',
#    '5. volume': '587355'},
#   '2025-03-03': {'1. open': '692.2500',
#    '2. high': '696.8500',
#    '3. low': '679.6500',
#    '4. close': '695.1500',
#    '5. volume': '398676'},
#   '2025-02-28': {'1. open': '701.8000',
#    '2. high': '701.8000',
#    '3. low': '682.8500',
#    '4. close': '688.2500',
#    '5. volume': '953162'},
#   '2025-02-27': {'1. open': '716.9000',
#    '2. high': '716.9000',
#    '3. low': '701.0000',
#    '4. close': '703.9500',
#    '5. volume': '624622'},
#   '2025-02-25': {'1. open': '719.0000',
#    '2. high': '719.0000',
#    '3. low': '709.9500',
#    '4. close': '711.0000',
#    '5. volume': '875612'},
#   '2025-02-24': {'1. open': '712.6500',
#    '2. high': '719.8000',
#    '3. low': '710.9000',
#    '4. close': '716.4000',
#    '5. volume': '525944'},
#   '2025-02-21': {'1. open': '729.2000',
#    '2. high': '732.0000',
#    '3. low': '720.0000',
#    '4. close': '721.5500',
#    '5. volume': '460425'},
#   '2025-02-20': {'1. open': '727.8000',
#    '2. high': '731.8000',
#    '3. low': '723.0500',
#    '4. close': '729.6500',
#    '5. volume': '279931'},
#   '2025-02-19': {'1. open': '722.8000',
#    '2. high': '734.7500',
#    '3. low': '722.1000',
#    '4. close': '726.8000',
#    '5. volume': '174597'},
#   '2025-02-18': {'1. open': '727.9500',
#    '2. high': '727.9500',
#    '3. low': '717.4500',
#    '4. close': '725.7500',
#    '5. volume': '396321'},
#   '2025-02-17': {'1. open': '721.8500',
#    '2. high': '728.9500',
#    '3. low': '711.4000',
#    '4. close': '728.0500',
#    '5. volume': '751026'},
#   '2025-02-14': {'1. open': '729.4500',
#    '2. high': '732.7000',
#    '3. low': '716.1500',
#    '4. close': '722.0000',
#    '5. volume': '895669'},
#   '2025-02-13': {'1. open': '735.0000',
#    '2. high': '737.3000',
#    '3. low': '726.0500',
#    '4. close': '727.3000',
#    '5. volume': '605466'},
#   '2025-02-12': {'1. open': '732.9500',
#    '2. high': '738.3000',
#    '3. low': '717.2500',
#    '4. close': '733.2500',
#    '5. volume': '550605'},
#   '2025-02-11': {'1. open': '738.1500',
#    '2. high': '740.0000',
#    '3. low': '726.9000',
#    '4. close': '731.0000',
#    '5. volume': '826170'},
#   '2025-02-10': {'1. open': '740.5500',
#    '2. high': '744.0500',
#    '3. low': '733.6000',
#    '4. close': '736.8500',
#    '5. volume': '788061'},
#   '2025-02-07': {'1. open': '761.8000',
#    '2. high': '761.8000',
#    '3. low': '732.0500',
#    '4. close': '737.0500',
#    '5. volume': '1805880'},
#   '2025-02-06': {'1. open': '769.6500',
#    '2. high': '770.9500',
#    '3. low': '750.0000',
#    '4. close': '752.3500',
#    '5. volume': '1384322'},
#   '2025-02-05': {'1. open': '780.8000',
#    '2. high': '781.6000',
#    '3. low': '764.6500',
#    '4. close': '766.1000',
#    '5. volume': '654303'},
#   '2025-02-04': {'1. open': '766.3000',
#    '2. high': '780.8500',
#    '3. low': '766.0000',
#    '4. close': '779.2000',
#    '5. volume': '749753'},
#   '2025-02-03': {'1. open': '763.6500',
#    '2. high': '763.6500',
#    '3. low': '753.4500',
#    '4. close': '761.0000',
#    '5. volume': '427934'},
#   '2025-01-31': {'1. open': '765.0000',
#    '2. high': '777.7500',
#    '3. low': '759.3500',
#    '4. close': '773.1000',
#    '5. volume': '241965'},
#   '2025-01-30': {'1. open': '759.4000',
#    '2. high': '764.8500',
#    '3. low': '754.7000',
#    '4. close': '762.2000',
#    '5. volume': '618809'},
#   '2025-01-29': {'1. open': '752.5000',
#    '2. high': '760.2500',
#    '3. low': '749.8000',
#    '4. close': '758.7000',
#    '5. volume': '379821'},
#   '2025-01-28': {'1. open': '756.2000',
#    '2. high': '759.6000',
#    '3. low': '745.6500',
#    '4. close': '751.6500',
#    '5. volume': '794022'},
#   '2025-01-27': {'1. open': '740.0000',
#    '2. high': '755.3000',
#    '3. low': '736.0000',
#    '4. close': '749.2000',
#    '5. volume': '775011'},
#   '2025-01-24': {'1. open': '747.2000',
#    '2. high': '753.7500',
#    '3. low': '738.8500',
#    '4. close': '744.3500',
#    '5. volume': '458033'},
#   '2025-01-23': {'1. open': '751.9500',
#    '2. high': '755.8000',
#    '3. low': '743.3000',
#    '4. close': '745.9500',
#    '5. volume': '235130'},
#   '2025-01-22': {'1. open': '762.8500',
#    '2. high': '762.8500',
#    '3. low': '738.3000',
#    '4. close': '753.2500',
#    '5. volume': '237866'},
#   '2025-01-21': {'1. open': '784.9500',
#    '2. high': '785.3000',
#    '3. low': '756.2500',
#    '4. close': '759.0000',
#    '5. volume': '953600'},
#   '2025-01-20': {'1. open': '765.0500',
#    '2. high': '784.9500',
#    '3. low': '765.0500',
#    '4. close': '779.0500',
#    '5. volume': '559123'},
#   '2025-01-17': {'1. open': '766.9000',
#    '2. high': '767.8500',
#    '3. low': '759.4500',
#    '4. close': '764.1000',
#    '5. volume': '497950'},
#   '2025-01-16': {'1. open': '761.6500',
#    '2. high': '776.5500',
#    '3. low': '760.0500',
#    '4. close': '766.4000',
#    '5. volume': '511761'},
#   '2025-01-15': {'1. open': '753.7000',
#    '2. high': '758.8500',
#    '3. low': '750.3500',
#    '4. close': '754.0000',
#    '5. volume': '171791'},
#   '2025-01-14': {'1. open': '730.6000',
#    '2. high': '756.9000',
#    '3. low': '730.6000',
#    '4. close': '748.1000',
#    '5. volume': '687121'},
#   '2025-01-13': {'1. open': '742.9500',
#    '2. high': '743.8500',
#    '3. low': '722.5000',
#    '4. close': '729.6000',
#    '5. volume': '300275'},
#   '2025-01-10': {'1. open': '760.3500',
#    '2. high': '760.8000',
#    '3. low': '742.0000',
#    '4. close': '743.1500',
#    '5. volume': '454472'},
#   '2025-01-09': {'1. open': '771.9500',
#    '2. high': '771.9500',
#    '3. low': '726.9000',
#    '4. close': '760.3500',
#    '5. volume': '803943'},
#   '2025-01-08': {'1. open': '781.0000',
#    '2. high': '782.5000',
#    '3. low': '760.1000',
#    '4. close': '771.2000',
#    '5. volume': '1224097'},
#   '2025-01-07': {'1. open': '778.0500',
#    '2. high': '783.7500',
#    '3. low': '775.1000',
#    '4. close': '779.0000',
#    '5. volume': '563547'},
#   '2025-01-06': {'1. open': '798.0000',
#    '2. high': '798.0000',
#    '3. low': '773.3000',
#    '4. close': '776.7500',
#    '5. volume': '624836'},
#   '2025-01-03': {'1. open': '801.9000',
#    '2. high': '809.7000',
#    '3. low': '792.2500',
#    '4. close': '793.5000',
#    '5. volume': '387698'},
#   '2025-01-02': {'1. open': '795.0000',
#    '2. high': '802.4000',
#    '3. low': '786.3000',
#    '4. close': '801.0500',
#    '5. volume': '711599'},
#   '2025-01-01': {'1. open': '796.8500',
#    '2. high': '798.5000',
#    '3. low': '789.6000',
#    '4. close': '793.3500',
#    '5. volume': '356031'},
#   '2024-12-31': {'1. open': '788.7500',
#    '2. high': '798.9500',
#    '3. low': '787.0000',
#    '4. close': '795.0500',
#    '5. volume': '283620'},
#   '2024-12-30': {'1. open': '802.7000',
#    '2. high': '808.0000',
#    '3. low': '785.2000',
#    '4. close': '788.3000',
#    '5. volume': '686161'},
#   '2024-12-27': {'1. open': '817.2500',
#    '2. high': '818.7500',
#    '3. low': '797.2500',
#    '4. close': '799.5500',
#    '5. volume': '1061163'},
#   '2024-12-26': {'1. open': '813.0000',
#    '2. high': '822.9500',
#    '3. low': '808.0000',
#    '4. close': '811.6500',
#    '5. volume': '194920'},
#   '2024-12-24': {'1. open': '825.0000',
#    '2. high': '825.5500',
#    '3. low': '809.2000',
#    '4. close': '811.8500',
#    '5. volume': '431577'},
#   '2024-12-23': {'1. open': '818.3500',
#    '2. high': '823.9000',
#    '3. low': '812.4000',
#    '4. close': '820.9500',
#    '5. volume': '281649'},
#   '2024-12-20': {'1. open': '833.8000',
#    '2. high': '836.4000',
#    '3. low': '810.0000',
#    '4. close': '812.5000',
#    '5. volume': '467910'},
#   '2024-12-19': {'1. open': '822.0500',
#    '2. high': '837.9000',
#    '3. low': '820.1000',
#    '4. close': '832.8000',
#    '5. volume': '309033'},
#   '2024-12-18': {'1. open': '850.2000',
#    '2. high': '850.8000',
#    '3. low': '836.7000',
#    '4. close': '839.0500',
#    '5. volume': '172425'},
#   '2024-12-17': {'1. open': '859.7500',
#    '2. high': '862.9500',
#    '3. low': '847.1500',
#    '4. close': '850.2000',
#    '5. volume': '143409'},
#   '2024-12-16': {'1. open': '859.0000',
#    '2. high': '866.2000',
#    '3. low': '857.8000',
#    '4. close': '860.7000',
#    '5. volume': '252691'},
#   '2024-12-13': {'1. open': '853.7000',
#    '2. high': '863.0000',
#    '3. low': '835.0000',
#    '4. close': '861.7000',
#    '5. volume': '455324'},
#   '2024-12-12': {'1. open': '862.5000',
#    '2. high': '864.2000',
#    '3. low': '851.2500',
#    '4. close': '853.7500',
#    '5. volume': '179011'},
#   '2024-12-11': {'1. open': '865.7500',
#    '2. high': '869.7500',
#    '3. low': '860.8000',
#    '4. close': '861.5500',
#    '5. volume': '342069'},
#   '2024-12-10': {'1. open': '862.0000',
#    '2. high': '868.8500',
#    '3. low': '858.5000',
#    '4. close': '867.6000',
#    '5. volume': '197287'},
#   '2024-12-09': {'1. open': '862.9500',
#    '2. high': '866.8000',
#    '3. low': '856.7500',
#    '4. close': '857.8500',
#    '5. volume': '646144'},
#   '2024-12-06': {'1. open': '866.9500',
#    '2. high': '875.5000',
#    '3. low': '856.8500',
#    '4. close': '864.0000',
#    '5. volume': '431320'},
#   '2024-12-05': {'1. open': '861.6500',
#    '2. high': '871.0000',
#    '3. low': '855.6500',
#    '4. close': '864.8500',
#    '5. volume': '379508'},
#   '2024-12-04': {'1. open': '854.4000',
#    '2. high': '863.8000',
#    '3. low': '850.2500',
#    '4. close': '859.4500',
#    '5. volume': '679548'},
#   '2024-12-03': {'1. open': '836.4500',
#    '2. high': '856.6000',
#    '3. low': '836.4500',
#    '4. close': '853.9500',
#    '5. volume': '370485'},
#   '2024-12-02': {'1. open': '836.2000',
#    '2. high': '842.0000',
#    '3. low': '832.8000',
#    '4. close': '836.2000',
#    '5. volume': '526054'},
#   '2024-11-29': {'1. open': '842.0000',
#    '2. high': '843.8500',
#    '3. low': '831.5000',
#    '4. close': '839.0000',
#    '5. volume': '757635'},
#   '2024-11-28': {'1. open': '834.9500',
#    '2. high': '845.7000',
#    '3. low': '830.3500',
#    '4. close': '838.7500',
#    '5. volume': '811586'},
#   '2024-11-27': {'1. open': '839.3000',
#    '2. high': '842.1500',
#    '3. low': '832.0000',
#    '4. close': '834.2000',
#    '5. volume': '502957'},
#   '2024-11-26': {'1. open': '844.7500',
#    '2. high': '846.7000',
#    '3. low': '835.2000',
#    '4. close': '839.3500',
#    '5. volume': '448647'},
#   '2024-11-25': {'1. open': '826.2500',
#    '2. high': '849.3000',
#    '3. low': '825.9500',
#    '4. close': '844.7500',
#    '5. volume': '1612713'},
#   '2024-11-22': {'1. open': '785.6500',
#    '2. high': '819.7500',
#    '3. low': '784.3000',
#    '4. close': '816.0500',
#    '5. volume': '1534393'},
#   '2024-11-21': {'1. open': '800.0000',
#    '2. high': '800.0000',
#    '3. low': '761.6500',
#    '4. close': '780.8500',
#    '5. volume': '804079'},
#   '2024-11-19': {'1. open': '817.5500',
#    '2. high': '820.1000',
#    '3. low': '800.1000',
#    '4. close': '802.0000',
#    '5. volume': '467072'},
#   '2024-11-18': {'1. open': '810.0500',
#    '2. high': '816.6500',
#    '3. low': '799.2000',
#    '4. close': '813.7000',
#    '5. volume': '378989'},
#   '2024-11-14': {'1. open': '809.9500',
#    '2. high': '817.8500',
#    '3. low': '801.1000',
#    '4. close': '804.0500',
#    '5. volume': '720597'},
#   '2024-11-13': {'1. open': '822.5000',
#    '2. high': '831.6500',
#    '3. low': '804.4500',
#    '4. close': '808.3500',
#    '5. volume': '454522'},
#   '2024-11-12': {'1. open': '851.0000',
#    '2. high': '853.0000',
#    '3. low': '824.1000',
#    '4. close': '826.4000',
#    '5. volume': '467134'},
#   '2024-11-11': {'1. open': '847.0000',
#    '2. high': '853.6500',
#    '3. low': '841.4500',
#    '4. close': '847.8000',
#    '5. volume': '1417460'},
#   '2024-11-08': {'1. open': '860.0000',
#    '2. high': '863.6500',
#    '3. low': '834.3000',
#    '4. close': '843.2500',
#    '5. volume': '1106664'},
#   '2024-11-07': {'1. open': '860.0500',
#    '2. high': '862.4500',
#    '3. low': '846.7000',
#    '4. close': '859.2500',
#    '5. volume': '494821'},
#   '2024-11-06': {'1. open': '850.0000',
#    '2. high': '861.0000',
#    '3. low': '846.2000',
#    '4. close': '854.7500',
#    '5. volume': '896339'},
#   '2024-11-05': {'1. open': '829.0000',
#    '2. high': '851.2000',
#    '3. low': '826.1000',
#    '4. close': '849.2000',
#    '5. volume': '1335383'},
#   '2024-11-04': {'1. open': '822.6500',
#    '2. high': '837.5000',
#    '3. low': '807.0500',
#    '4. close': '829.8500',
#    '5. volume': '458939'},
#   '2024-10-31': {'1. open': '821.9500',
#    '2. high': '828.0000',
#    '3. low': '813.4500',
#    '4. close': '820.5000',
#    '5. volume': '497763'},
#   '2024-10-30': {'1. open': '830.0000',
#    '2. high': '832.9000',
#    '3. low': '821.0500',
#    '4. close': '822.4000',
#    '5. volume': '322347'},
#   '2024-10-29': {'1. open': '796.5000',
#    '2. high': '834.5000',
#    '3. low': '790.5000',
#    '4. close': '832.6500',
#    '5. volume': '1593501'},
#   '2024-10-28': {'1. open': '783.2000',
#    '2. high': '803.9500',
#    '3. low': '783.2000',
#    '4. close': '792.0500',
#    '5. volume': '675658'},
#   '2024-10-25': {'1. open': '798.4500',
#    '2. high': '800.0000',
#    '3. low': '772.0500',
#    '4. close': '780.6000',
#    '5. volume': '650630'},
#   '2024-10-24': {'1. open': '786.0500',
#    '2. high': '796.8000',
#    '3. low': '784.5000',
#    '4. close': '794.7000',
#    '5. volume': '183971'},
#   '2024-10-23': {'1. open': '790.0000',
#    '2. high': '792.5000',
#    '3. low': '779.6000',
#    '4. close': '785.9500',
#    '5. volume': '467975'},
#   '2024-10-22': {'1. open': '814.1500',
#    '2. high': '816.3500',
#    '3. low': '787.6000',
#    '4. close': '790.4500',
#    '5. volume': '604778'},
#   '2024-10-21': {'1. open': '822.0500',
#    '2. high': '826.3500',
#    '3. low': '809.1000',
#    '4. close': '814.1500',
#    '5. volume': '584223'},
#   '2024-10-18': {'1. open': '811.0000',
#    '2. high': '822.4000',
#    '3. low': '803.1000',
#    '4. close': '819.9500',
#    '5. volume': '429099'},
#   '2024-10-17': {'1. open': '806.0500',
#    '2. high': '819.2500',
#    '3. low': '806.0500',
#    '4. close': '810.9000',
#    '5. volume': '948591'}}}

# %%
data2.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
prices = data2["Time Series (Daily)"]

# %%
import pandas as pd
df = pd.DataFrame(prices).T
df
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2025-03-12  729.9500  736.5000  719.2000  722.9000    198814
# 2025-03-11  724.9000  733.9000  722.5000  729.9500    285624
# 2025-03-10  732.9500  738.4500  727.0500  728.3500    339175
# 2025-03-07  732.9500  734.9000  727.9500  732.7500    288192
# 2025-03-06  737.9500  737.9500  727.1000  731.9500    321519
# ...              ...       ...       ...       ...       ...
# 2024-10-23  790.0000  792.5000  779.6000  785.9500    467975
# 2024-10-22  814.1500  816.3500  787.6000  790.4500    604778
# 2024-10-21  822.0500  826.3500  809.1000  814.1500    584223
# 2024-10-18  811.0000  822.4000  803.1000  819.9500    429099
# 2024-10-17  806.0500  819.2500  806.0500  810.9000    948591
#
# [100 rows x 5 columns]

# %%
df.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
# Convert all data to float
df = df.astype(float)

# %%
df.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2025-03-12', '2025-03-11', '2025-03-10', '2025-03-07',
#                '2025-03-06', '2025-03-05', '2025-03-04', '2025-03-03',
#                '2025-02-28', '2025-02-27', '2025-02-25', '2025-02-24',
#                '2025-02-21', '2025-02-20', '2025-02-19', '2025-02-18',
#                '2025-02-17', '2025-02-14', '2025-02-13', '2025-02-12',
#                '2025-02-11', '2025-02-10', '2025-02-07', '2025-02-06',
#                '2025-02-05', '2025-02-04', '2025-02-03', '2025-01-31',
#                '2025-01-30', '2025-01-29', '2025-01-28', '2025-01-27',
#                '2025-01-24', '2025-01-23', '2025-01-22', '2025-01-21',
#                '2025-01-20', '2025-01-17', '2025-01-16', '2025-01-15',
#                '2025-01-14', '2025-01-13', '2025-01-10', '2025-01-09',
#                '2025-01-08', '2025-01-07', '2025-01-06', '2025-01-03',
#                '2025-01-02', '2025-01-01', '2024-12-31', '2024-12-30',
#                '2024-12-27', '2024-12-26', '2024-12-24', '2024-12-23',
#                '2024-12-20', '2024-12-19', '2024-12-18', '2024-12-17',
#                '2024-12-16', '2024-12-13', '2024-12-12', '2024-12-11',
#                '2024-12-10', '2024-12-09', '2024-12-06', '2024-12-05',
#                '2024-12-04', '2024-12-03', '2024-12-02', '2024-11-29',
#                '2024-11-28', '2024-11-27', '2024-11-26', '2024-11-25',
#                '2024-11-22', '2024-11-21', '2024-11-19', '2024-11-18',
#                '2024-11-14', '2024-11-13', '2024-11-12', '2024-11-11',
#                '2024-11-08', '2024-11-07', '2024-11-06', '2024-11-05',
#                '2024-11-04', '2024-10-31', '2024-10-30', '2024-10-29',
#                '2024-10-28', '2024-10-25', '2024-10-24', '2024-10-23',
#                '2024-10-22', '2024-10-21', '2024-10-18', '2024-10-17'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.index.name = "Date"

# %%
df
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# Date
# 2025-03-12   729.95   736.50  719.20    722.90   198814.0
# 2025-03-11   724.90   733.90  722.50    729.95   285624.0
# 2025-03-10   732.95   738.45  727.05    728.35   339175.0
# 2025-03-07   732.95   734.90  727.95    732.75   288192.0
# 2025-03-06   737.95   737.95  727.10    731.95   321519.0
# ...             ...      ...     ...       ...        ...
# 2024-10-23   790.00   792.50  779.60    785.95   467975.0
# 2024-10-22   814.15   816.35  787.60    790.45   604778.0
# 2024-10-21   822.05   826.35  809.10    814.15   584223.0
# 2024-10-18   811.00   822.40  803.10    819.95   429099.0
# 2024-10-17   806.05   819.25  806.05    810.90   948591.0
#
# [100 rows x 5 columns]

# %%
df.to_csv("SBIN.csv")

# %% [markdown]
# ### Visualize candlestick chart

# %%
# %pip install plotly nbformat
# Out:
# Requirement already satisfied: plotly in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (6.0.0)
# Requirement already satisfied: nbformat in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: narwhals>=1.15.1 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from plotly) (1.25.2)
# Requirement already satisfied: packaging in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\priyanka\data_science\advanced python\repository\venv\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data = [
    go.Candlestick(
        x = df.index,
        open= df["1. open"],
        high = df["2. high"],
        low = df["3. low"],
        close = df["4. close"]
    )
])

fig.update_layout(width = 1200, height = 800)

fig.show()

# %%
type(fig)
# Out:
# plotly.graph_objs._figure.Figure

# %% [markdown]
# ### Create a class to get data for any stock

# %%
from dotenv import load_dotenv
import os
import pandas as pd
import requests
import plotly.graph_objects as go

# %%
class StockAPI:

    def __init__(self):
        # Load the api key
        load_dotenv()
        self.api_key = os.getenv("API_KEY")
        # Get the url
        self.url = "https://alpha-vantage.p.rapidapi.com/query"
        # Show the headers
        import requests
        self.headers = {
            "x-rapidapi-key": self.api_key,
            "x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
        }

    def symbol_search(self, company: str) -> dict:
        querystring = {
            "datatype" : "json",
            "keywords" : company,
            "function" : "SYMBOL_SEARCH",
        }
        response = requests.get(self.url, headers=self.headers, params=querystring)
        data = response.json()["bestMatches"]
        symbols = {}
        for i in data:
            s = i["1. symbol"]
            symbols[s] = [i["2. name"], i["4. region"], i["8. currency"]]
        # Return the symbols dictionary
        return symbols
    
    def get_daily_data(self, symbol:str) -> pd.DataFrame:
        querystring = {
            "function" : "TIME_SERIES_DAILY",
            "symbol" : symbol,
            "outputsize" : "compact",
            "datatype" : "json",
        }
        response = requests.get(self.url, headers= self.headers, params=querystring)
        data = response.json()["Time Series (Daily)"]
        # Convert into dataframe
        df = pd.DataFrame(data).T
        # Convert datatypes to float
        df = df.astype(float)
        # Convert index to datetime
        df.index = pd.to_datetime(df.index)
        # Provide a name to index
        df.index.name = "Date"
        return df
    
    def candlestick_chart(self, df: pd.DataFrame) -> go.Figure:
        fig = go.Figure(data = [
            go.Candlestick(
                x = df.index,
                open = df["1. open"],
                high = df["2. high"],
                low = df["3. low"],
                close = df["4. close"]
            )
        ])
        fig.update_layout(width = 1200, height = 800)
        return fig

# %% [markdown]
# ### Get the details for Tesla company stock

# %%
client = StockAPI()

# %%
client.symbol_search("Tesla")
# Out:
# {'TSLA': ['Tesla Inc', 'United States', 'USD'],
#  'TL0.DEX': ['Tesla Inc', 'XETRA', 'EUR'],
#  'TL0.FRK': ['Tesla Inc', 'Frankfurt', 'EUR'],
#  'TSLA34.SAO': ['Tesla Inc', 'Brazil/Sao Paolo', 'BRL'],
#  'TSLA.TRT': ['Tesla CDR (CAD Hedged)', 'Toronto', 'CAD'],
#  'TL01.FRK': ['TESLA INC. CDR DL-001', 'Frankfurt', 'EUR']}

# %%
df2 = client.get_daily_data("TSLA")
df2
# Out:
#             1. open   2. high   3. low  4. close    5. volume
# Date
# 2025-03-12  247.220  251.8400  241.100    248.09  142215681.0
# 2025-03-11  225.305  237.0649  217.020    230.58  174896415.0
# 2025-03-10  252.540  253.3700  220.000    222.15  185037825.0
# 2025-03-07  259.320  266.2499  250.730    262.67  102369640.0
# 2025-03-06  272.060  272.6500  260.020    263.45   98451566.0
# ...             ...       ...      ...       ...          ...
# 2024-10-22  217.310  218.2200  215.260    217.97   43268741.0
# 2024-10-21  218.900  220.4800  215.726    218.85   47328988.0
# 2024-10-18  220.710  222.2800  219.230    220.70   49611867.0
# 2024-10-17  221.590  222.0800  217.900    220.89   50791784.0
# 2024-10-16  221.400  222.8199  218.930    221.33   49632824.0
#
# [100 rows x 5 columns]

# %%
df2.to_csv("Tesla.csv")

# %%
fig2 = client.candlestick_chart(df2)
fig2.show()

# %% [markdown]
# ### Get details for HDFC bank in India

# %%
client.symbol_search("HDFC Bank")
# Out:
# {'HDB': ['HDFC Bank Ltd', 'United States', 'USD'],
#  'HDFCBANK.BSE': ['HDFC Bank Limited', 'India/Bombay', 'INR'],
#  'H1DB34.SAO': ['HDFC Bank Limited', 'Brazil/Sao Paolo', 'BRL'],
#  'HDFA.FRK': ['HDFC Bank Limited', 'Frankfurt', 'EUR']}

# %%
df3 = client.get_daily_data("HDFCBANK.BSE")
df3
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# Date
# 2025-03-12  1688.85  1719.00  1688.85   1711.85   884523.0
# 2025-03-11  1684.30  1694.40  1670.30   1684.95   118232.0
# 2025-03-10  1688.35  1699.40  1683.00   1687.05   150454.0
# 2025-03-07  1686.95  1700.90  1677.35   1689.35   320468.0
# 2025-03-06  1688.95  1700.00  1672.60   1689.75   268369.0
# ...             ...      ...      ...       ...        ...
# 2024-10-25  1757.00  1758.35  1729.00   1742.60   774016.0
# 2024-10-24  1737.55  1768.65  1737.55   1750.10   236712.0
# 2024-10-23  1702.30  1746.45  1702.30   1735.70   267503.0
# 2024-10-22  1729.00  1740.00  1710.95   1714.10   445656.0
# 2024-10-21  1720.05  1748.20  1710.50   1728.80  1400462.0
#
# [100 rows x 5 columns]

# %%
df3.to_csv("HDFC.csv")

# %%
fig3 = client.candlestick_chart(df3)
fig3.show()
